# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

# %%
'''
Your Code
'''
url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")


for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間：' + r.find_all(class_='article-meta-value')[3].text)

    except:
        continue
# Out:
# [BOX ] 2020東京奧運 - 阿根廷 97:77 日本
# 作者: laptic (靜夜聖林彼岸花)
# 時間：Sun Aug  1 14:33:56 2021
# (已被p刪除) <ras1203> 150字 2-1
# Re: [討論] 其實被酸躲弱區也沒啥好害怕的
# 作者: AbdulJabbar (Kareem Abdul-Jabbar)
# 時間：Sun Aug  1 14:56:16 2021
# [情報] Dwight Howard 有意回歸湖人隊
# 作者: thnlkj0665 (灰色地帶)
# 時間：Sun Aug  1 15:35:36 2021
# [Live] 奧運預賽 西班牙 VS 斯洛維尼亞
# 作者: Joyeeee (87)
# 時間：Sun Aug  1 15:50:00 2021
# Re: [討論] 其實被酸躲弱區也沒啥好害怕的
# 作者: HOlajuwon (Hakeem Olajuwon)
# 時間：Sun Aug  1 15:53:56 2021
# [情報] Melo對加入湖人隊非常感興趣
# 作者: la1aco (lalaco)
# 時間：Sun Aug  1 15:55:58 2021
# Re: [情報] Melo對加入湖人隊非常感興趣
# 作者: carotyao (汐止吳慷仁)
# 時間：Sun Aug  1 16:56:42 2021
# [BOX ] 2020東京奧運小組賽 ESP 87 vs 95 SLO
# [花邊] 美足球員不願接種疫苗 庫班稱願送輝瑞股票當誘因
# 作者: laptic (靜夜聖林彼岸花)
# 時間：Sun Aug  1 18:24:29 2021
# [新聞] 傳曾在詹皇家密會 紫金新三巨頭不怕改變
# 作者: arod1414 (Kawhi Leonard頭號粉絲)
# 時間：Sun Aug  1 18:26:52 2021
# [新聞] 斯洛維尼亞逆轉西班牙 唐西奇續寫國家隊
# 作者: GhostFather (鬼父Oni Chichi)
# 時間：Sun Aug  1 19:02:14 2021
# Re: [新聞] 傳曾在詹皇家密會 紫金新三巨頭不怕改變
# 作者: DoncicInPTT (東七七)
# 時間：Sun Aug  1 19:15:40 2021
# [花邊] 美國男籃 東京奧運八強戰將面對西班牙
# 作者: thnlkj0665 (灰色地帶)
# 時間：Sun Aug  1 19:34:51 2021
# [情報] 東京奧運男籃 八強賽對戰組合＆賽程
# 作者: Aotearoa (長白雲之鄉)
# 時間：Sun Aug  1 20:24:51 2021
# [公告] 板規v8.3
# [公告] NBA板救濟專案啟動 & 借用板主位置
# 作者: Vedan (百鬼組-味丹)
# 時間：Thu Jul 22 00:01:56 2021
# [公告] NBA板主徵選(7/23~8/20)
# 作者: Induction (愛人愛己)
# 時間：Fri Jul 23 10:37:09 2021
# [情報] 2021-22 自由市場 開市總整理
# [情報] 2021-22 自由市場 球隊異動表格 (8/1)

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
url = 'https://www.ptt.cc/bbs/NBA/index1.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")


for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間：' + r.find_all(class_='article-meta-value')[3].text)

    except:
        continue
# Out:
# 寫在 NBA 版的第九個球季之前
# 作者: Price (Price)
# 時間：Sun Oct 31 01:56:30 2004
# Re: [問題] 請問為何milicic都沒法上場？？？？
# 作者: SHB (森里螢一)
# 時間：Tue Nov 16 19:48:01 2004
# Re: melo......
# 作者: RickymarU (失蹤的力丸 )
# 時間：Tue Nov 16 23:16:02 2004
# [閒聊] penny
# 作者: baoerking (basketball)
# 時間：Thu Nov 18 21:01:29 2004
# Re: 灌籃次數排行板
# 作者: chinlingts (運動家的風度)
# 時間：Sat Nov 20 02:53:48 2004
# Re: 哇勒大亂鬥~~~~今天這場真是[email protected]@
# 作者: KOC (Godzilla)
# 時間：Sat Nov 20 15:41:18 2004
# [轉錄]（溜馬與活塞）後續發展  ~~by SHB
# 作者: Lyotard (painful)
# 時間：Sat Nov 20 16:56:30 2004
# Re:（溜馬與活塞）後續發展  ~~by SHB
# 作者: BIASONICA (sonic boom)
# 時間：Sat Nov 20 18:42:20 2004
# Re: [請益] 請問nba各隊看板人物...
# 作者: sunnyside (藏心無忌)
# 時間：Sat Nov 20 21:15:24 2004
# Re: Good times for Jazz started with Stockton
# 作者: temped (想要打動人心)
# 時間：Tue Nov 23 22:26:38 2004
# 十二月轉播表(未定)
# 作者: shanyaochung (好無聊喔)
# 時間：Tue Nov 23 22:50:03 2004
# 永遠的溜馬迷
# 作者: todaynow (day)
# 時間：Tue Nov 23 23:43:09 2004
# [公告] memi0605 浸水桶
# 作者: Lyotard (painful)
# 時間：Sat Nov 27 17:20:00 2004
# 十二月轉播時刻表
# 作者: Motola (超連結魔人)
# 時間：Sat Nov 27 18:14:54 2004
# Re: Hill 復活了,那Penny呢?
# 作者: Phatmen (大澤木小鐵)
# 時間：Mon Nov 29 00:35:29 2004
# Re: 不吐不快
# 作者: Phatmen (大澤木小鐵)
# 時間：Fri Dec  3 21:50:38 2004
# Re: 交易的新聞
# 作者: Finley (M姐好勁)
# 時間：Sat Dec  4 13:24:09 2004
# Re: [問題] NBA十大最難破的紀錄
# 作者: suendy (全國-碩士生徵友)
# 時間：Sat Dec  4 17:29:13 2004
# Players of the week
# 作者: Finley (M姐好勁)
# 時間：Tue Dec  7 11:14:56 2004
# [交易] 湖人與山貓的球員異動
# 作者: Lyotard (painful)
# 時間：Tue Dec  7 21:34:39 2004

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''

url = 'https://www.ptt.cc/bbs/Olympics_ISG/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")


for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間：' + r.find_all(class_='article-meta-value')[3].text)

    except:
        continue
# Out:
# Re: [問題] 為什麼台灣四面環海卻不盛行水類運動?
# 作者: wetteland ( )
# 時間：Sun Aug  1 20:12:03 2021
# Re: [快報] 中國準決賽跑進10秒內!!!!
# 作者: MRFROG (  跳)
# 時間：Sun Aug  1 20:12:28 2021
# Re: [快報] 中國準決賽跑進10秒內!!!!
# 作者: ppaauull ()
# 時間：Sun Aug  1 20:15:05 2021
# [心得] 羽球女單銅牌戰印度一姊加油! (不發錢
# 作者: p81827512 (inverse)
# 時間：Sun Aug  1 20:15:31 2021
# [問題] hami付費用戶被降畫質？
# 作者: Aaso (每度あり)
# 時間：Sun Aug  1 20:18:00 2021
# [心得] 李智凱等待落地的20年
# 作者: hannocps (拍劭)
# 時間：Sun Aug  1 20:18:10 2021
# Re: [問題] 一日鞍馬鞍迷請教
# 作者: oc4r (鐵桿爪迷)
# 時間：Sun Aug  1 20:19:02 2021
# [問題] 奧運馬拉松項目 台灣一個人都沒有?
# 作者: mozoa (矇著眼發文)
# 時間：Sun Aug  1 20:22:58 2021
# Re: [問題] 為什麼台灣四面環海卻不盛行水類運動?
# 作者: vi000246 (Vi)
# 時間：Sun Aug  1 20:22:58 2021
# [分享] 100m男子決賽奪冠機率
# 作者: swaggyyang (金所炫老公)
# 時間：Sun Aug  1 20:26:37 2021
# (本文已被刪除) <akira911>
# [快報] 桌球 中華女子團體 晉級8強
# 作者: linyuan0326 (郎朗)
# 時間：Sun Aug  1 20:30:23 2021
# [問題] 中國的女子羽球戰術？
# 作者: diesea08 (大木)
# 時間：Sun Aug  1 20:30:32 2021
# Re: [問題] 一日鞍馬鞍迷請教
# 作者: wade6510 (真情不必多說)
# 時間：Sun Aug  1 20:31:18 2021
# [快報] 小戴登場了!! 全台民眾來幫小戴加油吧!!
# 作者: kueiya (when you believe)
# 時間：Sun Aug  1 20:32:40 2021
# [問題] HamiVideo 開不起來
# 作者: kissa8443 (誠誠)
# 時間：Sun Aug  1 20:33:35 2021
# [奧運] 噓文就戴姐！？
# 作者: kinve1014 (黑松可樂)
# 時間：Sun Aug  1 20:36:27 2021
# Re: [問題] HamiVideo 開不起來
# 作者: shrinkage (Shrinkage)
# 時間：Sun Aug  1 20:36:30 2021
# Re: [問題] HamiVideo 開不起來
# 作者: Oldwood (老木)
# 時間：Sun Aug  1 20:37:18 2021
# [心得] 開不起來趕快去看公視
# 作者: livenotdie (吃漢味Wayne)
# 時間：Sun Aug  1 20:37:42 2021
# [公告] 板規 (2021.07.19)
# [情報] 8/1 東京奧運台灣轉播一覽表
# 作者: cjfnued (西街)
# 時間：Wed Jul 21 21:39:34 2021
# [LIVE] 桌球 18:30 台灣 VS 美國 女子團體
# 作者: dream2000 (築夢．逐夢)
# 時間：Sun Aug  1 08:35:37 2021
# [LIVE] 羽球 20:35 陳雨菲 VS 戴資穎
# 作者: lowes (Vamos)
# 時間：Sun Aug  1 11:30:00 2021
# [Live] 田徑  準決賽/決賽
# 作者: Wall62 ()
# 時間：Sun Aug  1 17:19:13 2021
